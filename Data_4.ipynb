# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('sample_pivot.csv')

# %%
df.head()
# Out:
#         Date Region                 Type  Units  Sales
# 0  7/11/2020   East  Children's Clothing   18.0    306
# 1  9/23/2020  North  Children's Clothing   14.0    448
# 2   4/2/2020  South     Women's Clothing   17.0    425
# 3  2/28/2020   East  Children's Clothing   26.0    832
# 4  3/19/2020   West     Women's Clothing    3.0     33

# %%
df.isnull().sum()
# Out:
# Date       0
# Region     0
# Type       0
# Units     89
# Sales      0
# dtype: int64

# %%
df.shape
# Out:
# (1000, 5)

# %%
df.dropna(inplace = True) #dropna is used to drop missing values alone while 
 #drop is for dropping the entire columns and rolls

# %%
df.shape
# Out:
# (911, 5)

# %%
pivot_df = pd.pivot_table(df, index = 'Region') #pivot is only used for satistical analysis

# %%
pivot_df
# Out:
#              Sales      Units
# Region
# East    408.182482  19.732360
# North   434.911894  19.202643
# South   432.956204  20.423358
# West    452.029412  19.294118

# %%
pivot_df= pd.pivot_table(df, index = ['Region','Type'], aggfunc = 'max')

# %%
pivot_df
# Out:
#                                  Date  Sales  Units
# Region Type
# East   Children's Clothing   9/5/2020   1122   35.0
#        Men's Clothing        9/7/2020   1054   35.0
#        Women's Clothing      9/9/2020   1054   35.0
# North  Children's Clothing   9/8/2020   1088   35.0
#        Women's Clothing      9/6/2020   1122   35.0
# South  Children's Clothing  9/25/2020    924   35.0
#        Men's Clothing        9/4/2020   1085   34.0
#        Women's Clothing     9/30/2020   1122   35.0
# West   Children's Clothing  9/20/2020    992   34.0
#        Men's Clothing       9/28/2020    930   35.0
#        Women's Clothing      9/8/2020   1023   33.0

# %%
pivot_df= pd.pivot_table(df, index = 'Region',columns = 'Type', aggfunc = 'max')

# %%
pivot_df
# Out:
#                       Date                                  \
# Type   Children's Clothing Men's Clothing Women's Clothing
# Region
# East              9/5/2020       9/7/2020         9/9/2020
# North             9/8/2020            NaN         9/6/2020
# South            9/25/2020       9/4/2020        9/30/2020
# West             9/20/2020      9/28/2020         9/8/2020
#
#                      Sales                                  \
# Type   Children's Clothing Men's Clothing Women's Clothing
# Region
# East                1122.0         1054.0           1054.0
# North               1088.0            NaN           1122.0
# South                924.0         1085.0           1122.0
# West                 992.0          930.0           1023.0
#
#                      Units
# Type   Children's Clothing Men's Clothing Women's Clothing
# Region
# East                  35.0           35.0             35.0
# North                 35.0            NaN             35.0
# ...

# %%
pivot_df= pd.pivot_table(df, index = 'Region',columns = 'Type',values = 'Sales', aggfunc = 'max')

# %%
pivot_df
# Out:
# Type    Children's Clothing  Men's Clothing  Women's Clothing
# Region
# East                 1122.0          1054.0            1054.0
# North                1088.0             NaN            1122.0
# South                 924.0          1085.0            1122.0
# West                  992.0           930.0            1023.0

# %%
pivot_df= pd.pivot_table(df, index = 'Region',columns = 'Type',values = 'Sales', aggfunc = 'max', margins = True)

# %%
pivot_df
# Out:
# Type    Children's Clothing  Men's Clothing  Women's Clothing   All
# Region
# East                 1122.0          1054.0            1054.0  1122
# North                1088.0             NaN            1122.0  1122
# South                 924.0          1085.0            1122.0  1122
# West                  992.0           930.0            1023.0  1023
# All                  1122.0          1085.0            1122.0  1122

# %%
pivot_df= pd.pivot_table(df, index = 'Region',columns = 'Type',values = 'Sales', aggfunc = 'max', margins = True, margins_name = 'Maximum')

# %%
pivot_df #under the pivot table any analysis carried out must be in the aggfunc table
# Out:
# Type     Children's Clothing  Men's Clothing  Women's Clothing  Maximum
# Region
# East                  1122.0          1054.0            1054.0     1122
# North                 1088.0             NaN            1122.0     1122
# South                  924.0          1085.0            1122.0     1122
# West                   992.0           930.0            1023.0     1023
# Maximum               1122.0          1085.0            1122.0     1122

# %%
gdp = pd.read_csv('RealGDP26072021.csv')

# %%
gdp
# Out:
#        tyear       Period  Agriculture  CropProduction  Livestock   Forestry  \
# 1981  Annual   2364373.15   1854764.44       341411.50   77897.99   90299.23
# 1982  Annual   2425960.89   1897078.85       361115.70   73910.25   93856.08
# 1983  Annual   2409081.92   1842704.31       393131.01   75282.78   97963.82
# 1984  Annual   2303505.42   1759115.15       399685.38   76694.14   68010.74
# 1985  Annual   2731062.47   2180907.71       428102.85   78082.45   43969.46
# ...      ...          ...          ...             ...        ...        ...
# 2018      Q4   4978775.48   4486166.16       341002.97   50038.06  101568.29
# 2018  Annual  17544147.74  15786437.68      1208128.04  182747.93  366834.08
# 2019      Q1   3597916.08   3144587.69       294971.65   42265.37  116091.37
# 2019      Q2   3857705.59   3443607.45       283559.35   49559.78   80979.01
# 2019      Q3   5408978.92   4994729.88       291218.38   44980.39   78050.27
#
# ...

# %%
rate = pd.read_csv('exchange26072021.csv')

# %%
rate
# Out:
#                   Rate Date  Currency Rate Year  Rate Month  Buying Rate  \
# 7/22/2021         US DOLLAR      2021      July    409.1400     409.6400
# 7/22/2021   POUNDS STERLING      2021      July    563.1812     563.8695
# 7/22/2021              EURO      2021      July    481.8851     482.4740
# 7/22/2021       SWISS FRANC      2021      July    444.7657     445.3093
# 7/22/2021               YEN      2021      July      3.7114       3.7159
# ...                     ...       ...       ...         ...          ...
# 12/10/2001              CFA      2001  December      0.1514       0.1521
# 12/10/2001             EURO      2001  December     99.3787      99.8230
# 12/10/2001             WAUA      2001  December    138.8876     139.5084
# 12/10/2001        US DOLLAR      2001  December    111.8500     112.3500
# 12/10/2001              YEN      2001  December      0.8881       0.8921
#
#             Central Rate  Selling Rate
# 7/22/2021       410.1400           NaN
# ...

# %%
rate.head()
# Out:
#                  Rate Date  Currency Rate Year  Rate Month  Buying Rate  \
# 7/22/2021        US DOLLAR      2021      July    409.1400     409.6400
# 7/22/2021  POUNDS STERLING      2021      July    563.1812     563.8695
# 7/22/2021             EURO      2021      July    481.8851     482.4740
# 7/22/2021      SWISS FRANC      2021      July    444.7657     445.3093
# 7/22/2021              YEN      2021      July      3.7114       3.7159
#
#            Central Rate  Selling Rate
# 7/22/2021      410.1400           NaN
# 7/22/2021      564.5577           NaN
# 7/22/2021      483.0629           NaN
# 7/22/2021      445.8528           NaN
# 7/22/2021        3.7204           NaN

# %%
rate.columns
# Out:
# Index(['Rate Date', 'Currency', 'Rate Year', 'Rate Month', 'Buying Rate',
#        'Central Rate', 'Selling Rate'],
#       dtype='object')

# %%
rate.reset_index(inplace = True)

# %%
rate
# Out:
#             index        Rate Date  Currency Rate Year  Rate Month  \
# 0       7/22/2021        US DOLLAR      2021      July    409.1400
# 1       7/22/2021  POUNDS STERLING      2021      July    563.1812
# 2       7/22/2021             EURO      2021      July    481.8851
# 3       7/22/2021      SWISS FRANC      2021      July    444.7657
# 4       7/22/2021              YEN      2021      July      3.7114
# ...           ...              ...       ...       ...         ...
# 46824  12/10/2001              CFA      2001  December      0.1514
# 46825  12/10/2001             EURO      2001  December     99.3787
# 46826  12/10/2001             WAUA      2001  December    138.8876
# 46827  12/10/2001        US DOLLAR      2001  December    111.8500
# 46828  12/10/2001              YEN      2001  December      0.8881
#
#        Buying Rate  Central Rate  Selling Rate
# 0         409.6400      410.1400           NaN
# 1         563.8695      564.5577           NaN
# ...

# %%
rate.rename({'index':'Rate Date','Rate Date' :'Currency', 'Currency':'Rate Year','Rate Year': 'Rate Month','Rate Month': 'Buying Rate','Buying Rate':
       'Central Rate','Central Rate' :'Selling Rate','Selling Rate':'m'},axis = 1, inplace = True)

# %%
rate
# Out:
#         Rate Date         Currency  Rate Year Rate Month  Buying Rate  \
# 0       7/22/2021        US DOLLAR       2021       July     409.1400
# 1       7/22/2021  POUNDS STERLING       2021       July     563.1812
# 2       7/22/2021             EURO       2021       July     481.8851
# 3       7/22/2021      SWISS FRANC       2021       July     444.7657
# 4       7/22/2021              YEN       2021       July       3.7114
# ...           ...              ...        ...        ...          ...
# 46824  12/10/2001              CFA       2001   December       0.1514
# 46825  12/10/2001             EURO       2001   December      99.3787
# 46826  12/10/2001             WAUA       2001   December     138.8876
# 46827  12/10/2001        US DOLLAR       2001   December     111.8500
# 46828  12/10/2001              YEN       2001   December       0.8881
#
#        Central Rate  Selling Rate   m
# 0          409.6400      410.1400 NaN
# 1          563.8695      564.5577 NaN
# ...

# %%
rate.drop(['Rate Year','Rate Month','m'],axis = 1, inplace = True)

# %%
rate
# Out:
#         Rate Date         Currency  Buying Rate  Central Rate  Selling Rate
# 0       7/22/2021        US DOLLAR     409.1400      409.6400      410.1400
# 1       7/22/2021  POUNDS STERLING     563.1812      563.8695      564.5577
# 2       7/22/2021             EURO     481.8851      482.4740      483.0629
# 3       7/22/2021      SWISS FRANC     444.7657      445.3093      445.8528
# 4       7/22/2021              YEN       3.7114        3.7159        3.7204
# ...           ...              ...          ...           ...           ...
# 46824  12/10/2001              CFA       0.1514        0.1521        0.1528
# 46825  12/10/2001             EURO      99.3787       99.8230      100.2670
# 46826  12/10/2001             WAUA     138.8876      139.5084      140.1293
# 46827  12/10/2001        US DOLLAR     111.8500      112.3500      112.8500
# 46828  12/10/2001              YEN       0.8881        0.8921        0.8961
#
# [46829 rows x 5 columns]

# %%
rate.head()
# Out:
#    Rate Date         Currency  Buying Rate  Central Rate  Selling Rate
# 0  7/22/2021        US DOLLAR     409.1400      409.6400      410.1400
# 1  7/22/2021  POUNDS STERLING     563.1812      563.8695      564.5577
# 2  7/22/2021             EURO     481.8851      482.4740      483.0629
# 3  7/22/2021      SWISS FRANC     444.7657      445.3093      445.8528
# 4  7/22/2021              YEN       3.7114        3.7159        3.7204

# %%
rate['Currency'].unique()
# Out:
# array(['US DOLLAR', 'POUNDS STERLING', 'EURO', 'SWISS FRANC', 'YEN',
#        'CFA', 'WAUA', 'YUAN/RENMINBI', 'RIYAL', 'DANISH KRONA',
#        'SOUTH AFRICAN RAND', 'SDR', 'POUND STERLING', 'DANISH KRONER',
#        'JAPANESE YEN', 'US DOLLAR ', 'YEN ', 'CFA ', 'WAUA ', 'SDR ',
#        'EURO\t', 'EURO ', 'RIYAL ', 'SWISS FRANC\t', 'SDR\t', 'NAIRA',
#        'POESO'], dtype=object)

# %%
rate.replace({'US DOLLAR':'USD','POUNDS STERLING':'POUNDS','SWISS FRANC':'SWISS',
       'YUAN/RENMINBI':'YUAN','DANISH KRONA':'KRONA',
       'SOUTH AFRICAN RAND':'RAND','POUND STERLING':'POUNDS','DANISH KRONER':'KRONA',
       'JAPANESE YEN':'YEN','US DOLLAR ':'USD',
       'EURO\t':'EURO','SWISS FRANC\t':'SWISS','SDR\t':'SDR'}, inplace = True)

# %%
rate
# Out:
#         Rate Date Currency  Buying Rate  Central Rate  Selling Rate
# 0       7/22/2021      USD     409.1400      409.6400      410.1400
# 1       7/22/2021   POUNDS     563.1812      563.8695      564.5577
# 2       7/22/2021     EURO     481.8851      482.4740      483.0629
# 3       7/22/2021    SWISS     444.7657      445.3093      445.8528
# 4       7/22/2021      YEN       3.7114        3.7159        3.7204
# ...           ...      ...          ...           ...           ...
# 46824  12/10/2001      CFA       0.1514        0.1521        0.1528
# 46825  12/10/2001     EURO      99.3787       99.8230      100.2670
# 46826  12/10/2001     WAUA     138.8876      139.5084      140.1293
# 46827  12/10/2001      USD     111.8500      112.3500      112.8500
# 46828  12/10/2001      YEN       0.8881        0.8921        0.8961
#
# [46829 rows x 5 columns]

# %%
rate['Currency'].unique() #to check duplicates
# Out:
# array(['USD', 'POUNDS', 'EURO', 'SWISS', 'YEN', 'CFA', 'WAUA', 'YUAN',
#        'RIYAL', 'KRONA', 'RAND', 'SDR', 'YEN ', 'CFA ', 'WAUA ', 'SDR ',
#        'EURO ', 'RIYAL ', 'NAIRA', 'POESO'], dtype=object)

# %%
rate.to_csv('update_exchange_rate.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e1bbf5b2588a> in <module>
# ----> 1 rate.to_csv('update_exchange_rate.csv')
#
# NameError: name 'rate' is not defined
